# %%
import pandas as pd
import numpy as np
import re

# %%
#Levantamos el archivo de trabajo
data_location = "properatti_limpio.csv"
data = pd.read_csv(data_location, sep=",")

# %%
data
# Out:
#         Unnamed: 0 property_type       place_name  \
# 0                0            PH        Mataderos
# 1                1     apartment         La Plata
# 2                2     apartment        Mataderos
# 3                3            PH          Liniers
# 4                4     apartment           Centro
# ...            ...           ...              ...
# 121215      121215     apartment         Belgrano
# 121216      121216         house           Beccar
# 121217      121217     apartment    Villa Urquiza
# 121218      121218     apartment      Plaza Colón
# 121219      121219     apartment  Capital Federal
#
#                           state_name  \
# 0                    Capital Federal
# 1             Bs.As. G.B.A. Zona Sur
# 2                    Capital Federal
# 3                    Capital Federal
# 4       Buenos Aires Costa Atlántica
# ...                              ...
# 121215               Capital Federal
# 121216      Bs.As. G.B.A. Zona Norte
# ...
